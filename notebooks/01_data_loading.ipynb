# %%
import pandas as pd
from sqlalchemy import create_engine

engine = create_engine(
    "postgresql://postgres:123@localhost:5433/telco_churn"
)

try:
    with engine.connect() as conn:
        print("Подключение к PostgreSQL успешно")
except Exception as e:
    print("Ошибка подключения:", e)
# Out:
# Подключение к PostgreSQL успешно

# %%
query = """
SELECT *
FROM clean.vw_churn_analysis
"""

df = pd.read_sql(query, engine)

print(f"Данные успешно загружены")
print(f"Размер датасета: {df.shape[0]:,} строк и {df.shape[1]} колонок")
print(df.info())
# Out:
# Данные успешно загружены
# Размер датасета: 7,043 строк и 27 колонок
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customerID                    7043 non-null   object
#  1   gender                        7043 non-null   object
#  2   Partner                       7043 non-null   object
#  3   Dependents                    7043 non-null   object
#  4   tenure                        7043 non-null   int64
#  5   PhoneService                  7043 non-null   object
#  6   MultipleLines                 7043 non-null   object
#  7   InternetService               7043 non-null   object
#  8   OnlineSecurity                7043 non-null   object
#  9   OnlineBackup                  7043 non-null   object
#  10  DeviceProtection              7043 non-null   object
#  11  TechSupport                   7043 non-null   object
#  12  StreamingTV                   7043 non-null   object
#  13  StreamingMovies               7043 non-null   object
#  14  Contract                      7043 non-null   object
#  15  PaperlessBilling              7043 non-null   object
#  16  PaymentMethod                 7043 non-null   object
#  17  MonthlyCharges                7043 non-null   float64
#  18  TotalCharges                  7043 non-null   float64
#  19  Churn                         7043 non-null   object
#  20  tenure_group                  7043 non-null   object
#  21  customer_type                 7043 non-null   object
#  22  avg_monthly_per_tenure_month  7032 non-null   float64
#  23  fiber_optic_flag              7043 non-null   int64
#  24  electronic_check_flag         7043 non-null   int64
#  25  month_to_month_flag           7043 non-null   int64
#  26  SeniorCitizen                 7043 non-null   int64
# dtypes: float64(3), int64(5), object(19)
# memory usage: 1.5+ MB
# None

# %%
numerical_cols = ['tenure', 'MonthlyCharges', 'TotalCharges']

str_cols = 'customerID'
df[str_cols] = df[str_cols].astype('string')

categorical_cols = df.select_dtypes(include='object').columns
df[categorical_cols] = df[categorical_cols].astype('category')

yes_no_cols = ['Partner', 'Dependents', 'PhoneService', 'PaperlessBilling', 'Churn']
df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')

df['SeniorCitizen'] = df['SeniorCitizen'].astype('int8')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 27 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   customerID                    7043 non-null   string
#  1   gender                        7043 non-null   category
#  2   Partner                       7043 non-null   int8
#  3   Dependents                    7043 non-null   int8
#  4   tenure                        7043 non-null   int64
#  5   PhoneService                  7043 non-null   int8
#  6   MultipleLines                 7043 non-null   category
#  7   InternetService               7043 non-null   category
#  8   OnlineSecurity                7043 non-null   category
#  9   OnlineBackup                  7043 non-null   category
#  10  DeviceProtection              7043 non-null   category
#  11  TechSupport                   7043 non-null   category
#  12  StreamingTV                   7043 non-null   category
#  13  StreamingMovies               7043 non-null   category
#  14  Contract                      7043 non-null   category
#  15  PaperlessBilling              7043 non-null   int8
#  16  PaymentMethod                 7043 non-null   category
#  17  MonthlyCharges                7043 non-null   float64
#  18  TotalCharges                  7043 non-null   float64
#  19  Churn                         7043 non-null   int8
#  20  tenure_group                  7043 non-null   category
#  21  customer_type                 7043 non-null   category
#  22  avg_monthly_per_tenure_month  7032 non-null   float64
#  23  fiber_optic_flag              7043 non-null   int64
#  24  electronic_check_flag         7043 non-null   int64
#  25  month_to_month_flag           7043 non-null   int64
#  26  SeniorCitizen                 7043 non-null   int8
# dtypes: category(13), float64(3), int64(4), int8(6), string(1)
# memory usage: 572.8 KB
# C:\Users\Artem\AppData\Local\Temp\ipykernel_11768\3384777421.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')
# C:\Users\Artem\AppData\Local\Temp\ipykernel_11768\3384777421.py:10: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')
# C:\Users\Artem\AppData\Local\Temp\ipykernel_11768\3384777421.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')
# C:\Users\Artem\AppData\Local\Temp\ipykernel_11768\3384777421.py:10: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')
# C:\Users\Artem\AppData\Local\Temp\ipykernel_11768\3384777421.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')
# C:\Users\Artem\AppData\Local\Temp\ipykernel_11768\3384777421.py:10: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')
# C:\Users\Artem\AppData\Local\Temp\ipykernel_11768\3384777421.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')
# C:\Users\Artem\AppData\Local\Temp\ipykernel_11768\3384777421.py:10: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')
# C:\Users\Artem\AppData\Local\Temp\ipykernel_11768\3384777421.py:10: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')
# C:\Users\Artem\AppData\Local\Temp\ipykernel_11768\3384777421.py:10: FutureWarning: The behavior of Series.replace (and DataFrame.replace) with CategoricalDtype is deprecated. In a future version, replace will only be used for cases that preserve the categories. To change the categories, use ser.cat.rename_categories instead.
#   df[yes_no_cols] = df[yes_no_cols].replace({'Yes': 1, 'No': 0}).astype('int8')

# %%
df.to_csv('../data/processed/telco_churn.csv', index=False)
df.to_parquet('../data/processed/telco_churn.parquet', index=False)
